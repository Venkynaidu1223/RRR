# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkynaidu1223/RRR/blob/main/Untitled62.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
 Given a list [10, 20, 0, 5], divide 100 by each element. Skip elements that cause exceptions.'''
l=[10,20,0,5]
s=0
for i in range(len(l)):
  try:
    s=s+100/l[i]
  except Exception as e:
    print(e)
  else:
    print("no problem")
print(s)
# Out:
# no problem
# no problem
# division by zero
# no problem
# 35.0

# %%
'''
7. Write a function that tries to convert a string into:

int
else float
if both fail → print "conversion failed" '''
s='venky'
try:
  d=int(s)*10
except Exception as e:
  print(e)
else:
  print("accepted")
# Out:
# invalid literal for int() with base 10: 'venky'

# %%
'''
Write a function that reads a number from input. If the user enters anything else, print "Invalid input" and ask again.
'''
x=1
c=0
while x>0:
  try :
    d=int(input())
    c=c+1
  except:
    print("hello bro enter the correct number")
    c=c+1
  else:
    x=x-1
    if(c>4):
      print(f"thanks bro , entering the correct details after several attempts {d} ")
    print(d)
# Out:
# 1
# 1

# %%
''' Given a list of strings, convert each to integer. If one fails, skip it and continue the loop. '''
l=[]
for i in range(10):
  l.append(chr(65+i))
print(l)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
s=0
for i in l:
  try :
    int(i)
  except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'A'
# invalid literal for int() with base 10: 'B'
# invalid literal for int() with base 10: 'C'
# invalid literal for int() with base 10: 'D'
# invalid literal for int() with base 10: 'E'
# invalid literal for int() with base 10: 'F'
# invalid literal for int() with base 10: 'G'
# invalid literal for int() with base 10: 'H'
# invalid literal for int() with base 10: 'I'
# invalid literal for int() with base 10: 'J'

# %%
 import logging as lg
 lg.debug("debug")

# %%
import kagglehub
path = kagglehub.dataset_download("iabhishekofficial/mobile-price-classification")
path
# Out:
# Using Colab cache for faster access to the 'mobile-price-classification' dataset.
# '/kaggle/input/mobile-price-classification'

# %%
import os
d=os.listdir(path)
d
# Out:
# ['train.csv', 'test.csv']

# %%
v=pd.read_csv("/kaggle/input/mobile-price-classification/train.csv")

# %%
v.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
v.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
v.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
import seaborn as sns
sns.heatmap(v.corr())
# Out:
# <Axes: >

# %%
v.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
v.shape
# Out:
# (2000, 21)

# %%
v.size
# Out:
# 42000

# %%
b1=v['battery_power'].quantile(0.25)
b3=v['battery_power'].quantile(0.75)
iqr=b3-b1
b33=b3+(iqr*(1.5))
b11=b1-(iqr*(1.5))
b33,b11
# Out:
# (np.float64(2760.5), np.float64(-293.5))

# %%
x=v[v['battery_power']==max(v['battery_power'])]

# %%
x
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1354           1998     1          1.2         0   8       0          31
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1354    0.6        196        8  ...         50      1356  2311    17     9
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 1354         18        1             1     0            2
#
# [1 rows x 21 columns]

# %%
def sam(x):
  b1=x.quantile(0.25)
  b3=x.quantile(0.75)
  iqr=b3-b1
  b33=b3+(iqr*(1.5))
  b11=b1-(iqr*(1.5))
  v=v[(v['battery_power']<b33 ) & (v['battery_power']>b11)]
  return v

# %%
v=v[(v['battery_power']<b33 ) & (v['battery_power']>b11)]
v
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
v.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
v['battery_power']=m.fit_transform(v[['battery_power']])
v
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0          0.227789     0          2.2         0   1       0           7
# 1          0.347361     1          0.5         1   0       1          53
# 2          0.041416     1          0.5         1   2       1          41
# 3          0.076152     1          2.5         0   0       0          10
# 4          0.881764     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995       0.195725     1          0.5         1   0       1           2
# 1996       0.977956     1          2.6         1   0       0          39
# 1997       0.941884     0          0.9         1   1       1          36
# 1998       0.675351     0          0.9         0   4       1          46
# 1999       0.006012     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
v
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0          0.227789     0          2.2         0   1       0           7
# 1          0.347361     1          0.5         1   0       1          53
# 2          0.041416     1          0.5         1   2       1          41
# 3          0.076152     1          2.5         0   0       0          10
# 4          0.881764     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995       0.195725     1          0.5         1   0       1           2
# 1996       0.977956     1          2.6         1   0       0          39
# 1997       0.941884     0          0.9         1   1       1          36
# 1998       0.675351     0          0.9         0   4       1          46
# 1999       0.006012     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
def sams(v,col):
  v[col]=m.fit_transform(v[[col]])
  return v
for i in v.columns:
  if i!
  print(sams(v,f'{i}'))
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0          0.227789     0          2.2         0   1       0           7
# 1          0.347361     1          0.5         1   0       1          53
# 2          0.041416     1          0.5         1   2       1          41
# 3          0.076152     1          2.5         0   0       0          10
# 4          0.881764     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995       0.195725     1          0.5         1   0       1           2
# 1996       0.977956     1          2.6         1   0       0          39
# 1997       0.941884     0          0.9         1   1       1          36
# 1998       0.675351     0          0.9         0   4       1          46
# 1999       0.006012     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
v
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 0          0.227789   0.0         0.68       0.0  0.052632     0.0
# 1          0.347361   1.0         0.00       1.0  0.000000     1.0
# 2          0.041416   1.0         0.00       1.0  0.105263     1.0
# 3          0.076152   1.0         0.80       0.0  0.000000     0.0
# 4          0.881764   1.0         0.28       0.0  0.684211     1.0
# ...             ...   ...          ...       ...       ...     ...
# 1995       0.195725   1.0         0.00       1.0  0.000000     1.0
# 1996       0.977956   1.0         0.84       1.0  0.000000     0.0
# 1997       0.941884   0.0         0.16       1.0  0.052632     1.0
# 1998       0.675351   0.0         0.16       0.0  0.210526     1.0
# 1999       0.006012   1.0         0.60       1.0  0.263158     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores  ...  px_height  px_width  \
# 0       0.080645  0.555556   0.900000  0.142857  ...   0.010204  0.170895
# ...

# %%
v.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
x=v[['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
       'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
       'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
       'touch_screen', 'wifi']]
y=v['price_range']

# %%
'''from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)'''

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
for i in v.columns:
  print(f'{i}')
# Out:
# battery_power
# blue
# clock_speed
# dual_sim
# fc
# four_g
# int_memory
# m_dep
# mobile_wt
# n_cores
# pc
# px_height
# px_width
# ram
# sc_h
# sc_w
# talk_time
# three_g
# touch_screen
# wifi
# price_range

# %%
d=pd.read_csv("/kaggle/input/mobile-price-classification/test.csv")
d.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
d.shape
# Out:
# (1000, 21)

# %%
for i in d.columns:
  sams(d,f'{i}')

# %%
d.head()
# Out:
#          id  battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 0  0.000000       0.362241   1.0         0.52       1.0  0.736842     0.0
# 1  0.001001       0.227485   1.0         0.00       1.0  0.210526     1.0
# 2  0.002002       0.871915   1.0         0.92       0.0  0.052632     0.0
# 3  0.003003       0.697799   0.0         0.00       1.0  0.947368     1.0
# 4  0.004004       0.623082   0.0         0.36       0.0  0.578947     1.0
#
#    int_memory     m_dep  mobile_wt  ...   pc  px_height  px_width       ram  \
# 0    0.048387  0.000000   0.941667  ...  0.8   0.118511  0.608550  0.862319
# 1    0.951613  0.777778   0.925000  ...  0.6   0.391190  0.237809  0.974772
# 2    0.403226  0.888889   0.883333  ...  0.2   0.665967  0.577822  0.572464
# 3    0.370968  0.444444   0.133333  ...  1.0   0.154693  0.835671  0.974235
# 4    0.758065  0.444444   0.233333  ...  0.9   0.392764  0.206413  0.405260
#
#        sc_h      sc_w  talk_time  three_g  touch_screen  wifi
# ...

# %%
d=d[[ 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc',
       'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
       'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
       'touch_screen', 'wifi']]

# %%
lr.predict(d)
# Out:
# array([ 8.42458922e-01,  9.65636566e-01,  7.24667615e-01,  1.15063564e+00,
#         4.14561713e-01,  9.17191909e-01,  1.20454037e+00,  3.48911488e-01,
#         8.73477766e-01, -3.02452492e-03,  1.11649335e+00,  1.07189593e+00,
#        -3.54758426e-05,  1.41520230e-01,  6.68092308e-01,  1.41938790e-01,
#         6.34444728e-01,  3.88058716e-01,  1.04032777e+00,  5.33053391e-01,
#         2.65767081e-01,  8.30029263e-01,  4.46739913e-01,  4.38858596e-01,
#         1.07346626e+00,  9.98273844e-03,  6.86302146e-01, -1.21765135e-01,
#         8.80773595e-01,  1.13515532e-02,  7.27863609e-01,  7.14461751e-02,
#         9.57131244e-01,  6.31277004e-02,  1.87888854e-01,  3.22830971e-01,
#         9.28268937e-01,  4.02186981e-01,  7.20440209e-01,  3.13910498e-01,
#         3.76464079e-01,  5.79987842e-01, -1.37611586e-01, -1.21430530e-01,
#         4.08997042e-04,  2.87877743e-01,  1.27036779e-01,  8.78373604e-01,
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr
# Out:
# LinearRegression()

# %%
d.columns
# Out:
# Index(['id', 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc',
#        'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %%
v.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
import sklearn
dir(sklearn.preprocessing)
# Out:
# ['Binarizer',
#  'FunctionTransformer',
#  'KBinsDiscretizer',
#  'KernelCenterer',
#  'LabelBinarizer',
#  'LabelEncoder',
#  'MaxAbsScaler',
#  'MinMaxScaler',
#  'MultiLabelBinarizer',
#  'Normalizer',
#  'OneHotEncoder',
#  'OrdinalEncoder',
#  'PolynomialFeatures',
#  'PowerTransformer',
#  'QuantileTransformer',
#  'RobustScaler',
#  'SplineTransformer',
#  'StandardScaler',
#  'TargetEncoder',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_csr_polynomial_expansion',
#  '_data',
#  '_discretization',
#  '_encoders',
#  '_function_transformer',
#  '_label',
#  '_polynomial',
#  '_target_encoder',
#  '_target_encoder_fast',
#  'add_dummy_feature',
#  'binarize',
#  'label_binarize',
#  'maxabs_scale',
#  'minmax_scale',
#  'normalize',
#  'power_transform',
#  'quantile_transform',
#  'robust_scale',
#  'scale']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae  = mean_absolute_error(y_test, y_pred)
mse  = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("MAE :", mae)
print("MSE :", mse)
print("RMSE:", rmse)
# Out:
# MAE : 0.09111868265861302
# MSE : 0.011471238024730294
# RMSE: 0.10710386559191173
